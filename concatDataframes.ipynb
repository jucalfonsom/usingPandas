# %%
import pandas as pd
import numpy as np

# %%
pd.options.display.float_format = '{:.2f}'.format

# %%
np.set_printoptions(precision=2)

# %% [markdown]
# # Concantenate numpy

# %%
x1 = np.random.rand(2, 5) * 10
x1
# Out:
# array([[1.11, 9.07, 7.09, 8.02, 2.4 ],
#        [0.85, 3.84, 0.09, 9.45, 5.82]])

# %%
x2 = np.random.rand(2, 5) * -1
x2
# Out:
# array([[-0.44, -0.44, -0.92, -0.72, -0.55],
#        [-0.55, -0.8 , -0.57, -0.57, -0.37]])

# %%
np.concatenate([x1, x2])
# Out:
# array([[ 1.11,  9.07,  7.09,  8.02,  2.4 ],
#        [ 0.85,  3.84,  0.09,  9.45,  5.82],
#        [-0.44, -0.44, -0.92, -0.72, -0.55],
#        [-0.55, -0.8 , -0.57, -0.57, -0.37]])

# %%
np.concatenate([x1, x2]).shape
# Out:
# (4, 5)

# %%
np.concatenate([x1, x2], axis = 1)
# Out:
# array([[ 1.11,  9.07,  7.09,  8.02,  2.4 , -0.44, -0.44, -0.92, -0.72,
#         -0.55],
#        [ 0.85,  3.84,  0.09,  9.45,  5.82, -0.55, -0.8 , -0.57, -0.57,
#         -0.37]])

# %%
np.concatenate([x1, x2], axis = 1).shape
# Out:
# (2, 10)

# %% [markdown]
# # Concatenate Pandas

# %%
s1 = pd.Series(x1[0], index=['a', 'b', 'c', 'd', 'e'])
s1
# Out:
# a   1.11
# b   9.07
# c   7.09
# d   8.02
# e   2.40
# dtype: float64

# %%
s2 = pd.Series(x2[0], index=['c', 'd', 'e', 'f', 'g'])
s2
# Out:
# c   -0.44
# d   -0.44
# e   -0.92
# f   -0.72
# g   -0.55
# dtype: float64

# %%
pd.concat([s1, s2])
# Out:
# a    1.11
# b    9.07
# c    7.09
# d    8.02
# e    2.40
# c   -0.44
# d   -0.44
# e   -0.92
# f   -0.72
# g   -0.55
# dtype: float64

# %%
pd.concat([s1, s2], axis=1)
# Out:
#      0     1
# a 1.11   NaN
# b 9.07   NaN
# c 7.09 -0.44
# d 8.02 -0.44
# e 2.40 -0.92
# f  NaN -0.72
# g  NaN -0.55

# %% [markdown]
# # Concatenate Dataframes

# %%
df1 = pd.DataFrame(np.random.rand(3, 2)*10, columns=['a', 'b'])
df1
# Out:
#      a    b
# 0 7.43 5.26
# 1 2.77 5.77
# 2 9.80 7.74

# %%
df2 = pd.DataFrame(np.random.rand(3, 2)*-1, columns=['a', 'b'], index=[2, 3, 4])
df2
# Out:
#       a     b
# 2 -0.28 -0.55
# 3 -0.49 -0.41
# 4 -0.96 -0.55

# %%
pd.concat([df1, df2])
# Out:
#       a     b
# 0  7.43  5.26
# 1  2.77  5.77
# 2  9.80  7.74
# 2 -0.28 -0.55
# 3 -0.49 -0.41
# 4 -0.96 -0.55

# %%
pd.concat([df1, df2], axis=1)
# Out:
#      a    b     a     b
# 0 7.43 5.26   NaN   NaN
# 1 2.77 5.77   NaN   NaN
# 2 9.80 7.74 -0.28 -0.55
# 3  NaN  NaN -0.49 -0.41
# 4  NaN  NaN -0.96 -0.55

# %%
pd.concat([df1, df2], axis=1, join='inner')
# Out:
#      a    b     a     b
# 2 9.80 7.74 -0.28 -0.55

# %%
# Reset index

pd.concat([
    df1.reset_index(drop=True), 
    df2.reset_index(drop=True)
    ], axis=1)
# Out:
#      a    b     a     b
# 0 7.43 5.26 -0.28 -0.55
# 1 2.77 5.77 -0.49 -0.41
# 2 9.80 7.74 -0.96 -0.55

# %%
df1.append(df2)
# Out:
#       a     b
# 0  7.43  5.26
# 1  2.77  5.77
# 2  9.80  7.74
# 2 -0.28 -0.55
# 3 -0.49 -0.41
# 4 -0.96 -0.55

# %%
# Traspouse of dataframe

df1.T
# Out:
#      0    1    2
# a 7.43 2.77 9.80
# b 5.26 5.77 7.74

# %%
# Append dataframes for columns

df1.T.append(df2.T).T
# Out:
#      a    b     a     b
# 0 7.43 5.26   NaN   NaN
# 1 2.77 5.77   NaN   NaN
# 2 9.80 7.74 -0.28 -0.55
# 3  NaN  NaN -0.49 -0.41
# 4  NaN  NaN -0.96 -0.55
