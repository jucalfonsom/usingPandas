# %%
import pandas as pd
pd.__version__
# Out:
# '1.2.3'

# %%
import numpy as np

# %%
dict_data = {
    'edad': [10,9,13,14,12,11,12],
    'cm': [115,110,130,155,125,120,125],
    'pais':['co','mx','co','mx','mx','ch','ch'],
    'genero':['M','F','F','M','M','M','F'],
    'Q1':[5,10,8,np.nan,7,8,3],
    'Q2':[7,9,9,8,8,8,9]
}

# %%
df = pd.DataFrame(dict_data)
df
# Out:
#    edad   cm pais genero    Q1  Q2
# 0    10  115   co      M   5.0   7
# 1     9  110   mx      F  10.0   9
# 2    13  130   co      F   8.0   9
# 3    14  155   mx      M   NaN   8
# 4    12  125   mx      M   7.0   8
# 5    11  120   ch      M   8.0   8
# 6    12  125   ch      F   3.0   9

# %%
df = pd.DataFrame(dict_data, index = ['ana','benito','camilo','daniel','erika','fabian','gabriela'])
df
# Out:
#           edad   cm pais genero    Q1  Q2
# ana         10  115   co      M   5.0   7
# benito       9  110   mx      F  10.0   9
# camilo      13  130   co      F   8.0   9
# daniel      14  155   mx      M   NaN   8
# erika       12  125   mx      M   7.0   8
# fabian      11  120   ch      M   8.0   8
# gabriela    12  125   ch      F   3.0   9

# %%
df.index
# Out:
# Index(['ana', 'benito', 'camilo', 'daniel', 'erika', 'fabian', 'gabriela'], dtype='object')

# %%
df.columns
# Out:
# Index(['edad', 'cm', 'pais', 'genero', 'Q1', 'Q2'], dtype='object')

# %%
df.values
# Out:
# array([[10, 115, 'co', 'M', 5.0, 7],
#        [9, 110, 'mx', 'F', 10.0, 9],
#        [13, 130, 'co', 'F', 8.0, 9],
#        [14, 155, 'mx', 'M', nan, 8],
#        [12, 125, 'mx', 'M', 7.0, 8],
#        [11, 120, 'ch', 'M', 8.0, 8],
#        [12, 125, 'ch', 'F', 3.0, 9]], dtype=object)

# %%
df['edad']
# Out:
# ana         10
# benito       9
# camilo      13
# daniel      14
# erika       12
# fabian      11
# gabriela    12
# Name: edad, dtype: int64

# %%
df[['edad', 'cm', 'Q1']]
# Out:
#           edad   cm    Q1
# ana         10  115   5.0
# benito       9  110  10.0
# camilo      13  130   8.0
# daniel      14  155   NaN
# erika       12  125   7.0
# fabian      11  120   8.0
# gabriela    12  125   3.0

# %%
df.loc['ana', ['edad', 'cm', 'Q1']]
# Out:
# edad     10
# cm      115
# Q1      5.0
# Name: ana, dtype: object

# %%
df.loc[['ana', 'erika'], ['edad', 'cm', 'Q1']]
# Out:
#        edad   cm   Q1
# ana      10  115  5.0
# erika    12  125  7.0

# %%
df.loc['daniel', 'Q1']
# Out:
# nan

# %%
df.iloc[2, 1]
# Out:
# 130

# %%
df.iloc[2, [1, 3]]
# Out:
# cm        130
# genero      F
# Name: camilo, dtype: object

# %%
df.iloc[[2, 4, 5], [1, 3]]
# Out:
#          cm genero
# camilo  130      F
# erika   125      M
# fabian  120      M

# %%
df.iloc[:,[1,3]]
# Out:
#            cm genero
# ana       115      M
# benito    110      F
# camilo    130      F
# daniel    155      M
# erika     125      M
# fabian    120      M
# gabriela  125      F

# %%
df['edad']>12
# Out:
# ana         False
# benito      False
# camilo       True
# daniel       True
# erika       False
# fabian      False
# gabriela    False
# Name: edad, dtype: bool

# %%
df[df['edad']>=12]
# Out:
#           edad   cm pais genero   Q1  Q2
# camilo      13  130   co      F  8.0   9
# daniel      14  155   mx      M  NaN   8
# erika       12  125   mx      M  7.0   8
# gabriela    12  125   ch      F  3.0   9

# %%
df[(df['edad']>=12) & (df['pais']=='mx')]
# Out:
#         edad   cm pais genero   Q1  Q2
# daniel    14  155   mx      M  NaN   8
# erika     12  125   mx      M  7.0   8

# %%
df.query('edad>=12')
# Out:
#           edad   cm pais genero   Q1  Q2
# camilo      13  130   co      F  8.0   9
# daniel      14  155   mx      M  NaN   8
# erika       12  125   mx      M  7.0   8
# gabriela    12  125   ch      F  3.0   9

# %%
df[df['Q2']>=df['Q1']]
# Out:
#           edad   cm pais genero   Q1  Q2
# ana         10  115   co      M  5.0   7
# camilo      13  130   co      F  8.0   9
# erika       12  125   mx      M  7.0   8
# fabian      11  120   ch      M  8.0   8
# gabriela    12  125   ch      F  3.0   9

# %% [markdown]
# # Saving and loading files

# %%
# !pwd
# Out:
# /mnt/c/Users/j_cam/Documents/Proyectos/usingPandas

# %%
# !mkdir /mnt/c/Users/j_cam/Documents/Proyectos/usingPandas/db

# %%
dir_pandas = '/mnt/c/Users/j_cam/Documents/Proyectos/usingPandas/db/{}'.format('test.csv')
dir_pandas
# Out:
# '/mnt/c/Users/j_cam/Documents/Proyectos/usingPandas/db/test.csv'

# %%
df.to_csv(dir_pandas, index=False)

# %%
df_read = pd.read_csv(dir_pandas)
df_read
# Out:
#    edad   cm pais genero    Q1  Q2
# 0    10  115   co      M   5.0   7
# 1     9  110   mx      F  10.0   9
# 2    13  130   co      F   8.0   9
# 3    14  155   mx      M   NaN   8
# 4    12  125   mx      M   7.0   8
# 5    11  120   ch      M   8.0   8
# 6    12  125   ch      F   3.0   9

# %%
current_dir = '/mnt/c/Users/j_cam/Documents/Proyectos/usingPandas/db/{}'
current_dir
# Out:
# '/mnt/c/Users/j_cam/Documents/Proyectos/usingPandas/db/{}'
